# %% [markdown]
# <a href="https://colab.research.google.com/github/ikyyyyy/PythonForDataEngineering/blob/main/Python_Numbers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(1+2)
# Out:
# 3

# %%
5+9
# Out:
# 14

# %%
1/2
# Out:
# 0.5

# %%
1//2
# Out:
# 0

# %%
2**3
# Out:
# 8

# %%
2 + 10 * 8
# Out:
# 82

# %%
(2 + 10) * 8
# Out:
# 96

# %%
2 + (10 * 8)
# Out:
# 82

# %%
number1 = 5
number2 = 1.2

# %%
number1 + number2
# Out:
# 6.2

# %%
number1 * number2
# Out:
# 6.0

# %%
number1 = 5
number2 = 2
mean = (number1 + number2)/2
mean
# Out:
# 3.5
