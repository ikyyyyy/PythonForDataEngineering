# %% [markdown]
# <a href="https://colab.research.google.com/github/ikyyyyy/PythonForDataEngineering/blob/main/Python_Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello, World!')
# Out:
# Hello, World!

# %%
print("Ferd Ikram")
# Out:
# Ferd Ikram

# %%
str = "Hello"

# %%
str[-1]
# Out:
# 'o'

# %%
str[0]
# Out:
# 'H'

# %%
str[4]
# Out:
# 'o'

# %%
str[-4]
# Out:
# 'e'

# %%
str[2:4]
# Out:
# 'll'

# %%
str[2:]
# Out:
# 'llo'

# %%
str1 = 'hello'
str2 = "Ikram"

# %%
str1 + " " + str2
# Out:
# 'hello Ikram'

# %%
str1 * 5
# Out:
# 'hellohellohellohellohello'

# %%
( str1 + " " )* 5
# Out:
# 'hello hello hello hello hello '

# %%
str2[-3:]
# Out:
# 'ram'

# %%
str2[:-3]
# Out:
# 'Ik'

# %%
str2[-1:]
# Out:
# 'm'

# %%
print('m' in str2)
# Out:
# True

# %%
print('ram' in str2)
# Out:
# True

# %%
print('ik' in str2)
# Out:
# False

# %%
print('ik' in str2.lower())
# Out:
# True

# %%
str1.lower()
# Out:
# 'hello'

# %%
str1.upper()
# Out:
# 'HELLO'

# %%
type(str1)
# Out:
# str

# %%
str1.capitalize()
# Out:
# 'Hello'

# %%
firstName = "Ikram"
lastName = "Ferd"
student = True

print("I'am %s %s and it's is %s that I am a student" %(firstName, lastName, student))

print("I'am {} {} and it's is {} that I am a student".format(firstName, lastName, student))
# Out:
# I'am Ikram Ferd and it's is True that I am a student
# I'am Ikram Ferd and it's is True that I am a student
